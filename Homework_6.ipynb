# %% [markdown]
# <a href="https://colab.research.google.com/github/andrea-richard/ai-science-training-series/blob/main/Homework_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# These are the screenshots I have from running the provided commands on Sophia

# %% [markdown]
# ![Homework 6 - proof.png](data:image/png;base64,...)

# %% [markdown]
# ![hw 6 - proof 2.png](data:image/png;base64,...)
